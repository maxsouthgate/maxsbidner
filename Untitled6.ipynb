# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv('survey lung cancer.csv')



df.head()

df["GENDER"].value_counts()


mylabels=["Men", "Women"]

plt.pie(values, labels = mylabels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1274a6730>,
# ...
#  [Text(-0.08379621843597737, 1.0968036258947316, 'Men'),
#   Text(0.083796218435977, -1.0968036258947316, 'Women')],
#  [Text(-0.045707028237805834, 0.598256523215308, '52.4%'),
#   Text(0.045707028237805626, -0.598256523215308, '47.6%')])

# %%
df.groupby(['AGE', 'GENDER']).size().unstack().plot(kind='bar',stacked=False)
plt.show()

# %%
df.groupby(['AGE', 'LUNG_CANCER']).size().unstack().plot(kind='bar',stacked=False)
plt.show()

# %%
df.groupby(['GENDER', 'LUNG_CANCER']).size().unstack().plot(kind='bar',stacked=False)
plt.show()
